# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Data_Set/laptop_data (1).csv')

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %% [raw]
# # Remove Unwanted thing

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %% [raw]
# # Change Datatype

# %%
df['Ram'] = df['Ram'].astype(int)
df['Weight'] = df['Weight'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
sns.displot(x='Price', data=df)
plt.show()

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='Company', y='Price', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='TypeName', y='Price', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
sns.displot(df['Inches'], kde=True)
plt.show()

# %%
sns.scatterplot(x=df['Inches'], y=df['Price'])
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 189     Dell            Notebook    17.3                Full HD 1920x1080
# 730     Acer              Gaming    17.3      IPS Panel Full HD 1920x1080
# 157     Asus  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 1160  Lenovo           Ultrabook    14.0                Full HD 1920x1080
# 526   Lenovo            Notebook    15.6                Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 189    Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
# 730   Intel Core i7 6700HQ 2.6GHz   16  128GB SSD +  1TB HDD
# 157    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 1160   Intel Core i7 6600U 2.6GHz    8             256GB SSD
# 526    Intel Core i7 7500U 2.7GHz    4               1TB HDD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen
# 189            AMD Radeon 530  Windows 10     2.8   57808.80            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Touchscreen'], y=df['Price'])
plt.show()

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['IPS'], y=df['Price'])
plt.show()

# %%
# df['Resolution'] = df['ScreenResolution'].apply(lambda x: x.split()[-1])

# %%
new = df['ScreenResolution'].str.split('x', n=1, expand=True)

# %%
new.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['x_res'] = new[0]
df['y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_res'] = (df['x_res'].str.replace(',','').str.split().str[-1])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# Name: Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(9)
# ...

# %%
df['x_res'] = df['x_res'].astype(int)
df['y_res'] = df['y_res'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS  x_res  y_res
# 0    1.37  71378.6832            0    1   2560   1600

# %%
df['ppi'] = (((df['x_res'])*2)+((df['y_res'])*2)**0.5/df['Inches']).astype(float)

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS  x_res  y_res          ppi
# 0    1.37  71378.6832            0    1   2560   1600  5124.253274

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# ppi            0.556501
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'], inplace=True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
#
#    x_res  y_res          ppi
# 0   2560   1600  5124.253274

# %%
df.drop(columns=['Inches','x_res','y_res'], inplace=True)

# %%
df.head(1)
# Out:
#   Company   TypeName                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
#
#            ppi
# 0  5124.253274

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df.head(2)
# Out:
#   Company   TypeName                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#            ppi       Cpu Name
# 0  5124.253274  Intel Core i5
# 1  2883.189955  Intel Core i5

# %%
df['Cpu Name'].value_counts()
# Out:
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
def featch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'other Inter Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(featch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#            ppi       Cpu Name      Cpu Brand
# ...

# %%
df['Cpu Brand'].value_counts()
# Out:
# Intel Core i7            527
# Intel Core i5            423
# other Inter Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: Cpu Brand, dtype: int64

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Cpu Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu Name', 'Cpu'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS          ppi      Cpu Brand
# 0  macOS    1.37   71378.6832            0    1  5124.253274  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  2883.189955  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  3842.979218  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  5763.896104  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  5124.253274  Intel Core i5

# %%
df['Ram'].value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Ram'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['SSD']=0
df['HDD']=0
df['Flash']=0
df['Hybrid']=0

for i in df.index:
    memory=df.loc[i,'Memory']
    
    parts=memory.split(' + ')
    
    for part in parts:
        if 'SSD' in part:
            df.loc[i,'SSD']=float(part.split('GB')[0].split('TB')[0])
            
        elif 'HDD' in part:
            df.loc[i,'HDD']=float(part.split('GB')[0].split('TB')[0])
            
        elif 'Flash Storage' in part:
            df.loc[i,'Flash']=float(part.split('GB')[0].split('TB')[0])
            
        elif 'Hybrid' in part:            
            df.loc[i,'Hybrid']=float(part.split('GB')[0].split('TB')[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS          ppi      Cpu Brand  \
# 0  macOS    1.37   71378.6832            0    1  5124.253274  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  2883.189955  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  3842.979218  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  5763.896104  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  5124.253274  Intel Core i5
#
#    SSD  HDD  Flash  Hybrid
# ...

# %%
df.sample(5)
# Out:
#     Company   TypeName  Ram                Memory                         Gpu  \
# 762  Google  Ultrabook    8             256GB SSD       Intel HD Graphics 615
# 578     MSI     Gaming   16  512GB SSD +  1TB HDD     Nvidia GeForce GTX 1070
# 304    Asus     Gaming    8  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti
# 951    Dell  Ultrabook    8             256GB SSD       Intel HD Graphics 620
# 700    Dell     Gaming    8               1TB HDD     Nvidia GeForce GTX 1050
#
#           OpSys  Weight      Price  Touchscreen  IPS          ppi  \
# 762   Chrome OS    1.10   83063.52            1    0  4804.599068
# 578  Windows 10    4.14  145401.12            0    0  3842.686462
# 304  Windows 10    2.50   67399.20            0    0  3842.979218
# 951  Windows 10    1.36   94572.00            0    0  3843.319700
# 700  Windows 10    2.56   43636.32            0    0  3842.979218
#
#          Cpu Brand  SSD  HDD  Flash  Hybrid
# 762  Intel Core i5  256    0      0       0
# ...

# %%
df.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# ppi            0.556501
# SSD            0.553199
# HDD           -0.234897
# Flash         -0.040511
# Hybrid        -0.004769
# Name: Price, dtype: float64

# %%
df.drop(columns=['Flash','Hybrid','Memory'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS          ppi      Cpu Brand  SSD  HDD
# 0   71378.6832            0    1  5124.253274  Intel Core i5  128    0
# 1   47895.5232            0    0  2883.189955  Intel Core i5    0    0
# 2   30636.0000            0    0  3842.979218  Intel Core i5  256    0
# 3  135195.3360            0    1  5763.896104  Intel Core i7  512    0
# 4   96095.8080            0    1  5124.253274  Intel Core i5  256    0

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS          ppi      Cpu Brand  SSD  HDD  \
# 0   71378.6832            0    1  5124.253274  Intel Core i5  128    0
# 1   47895.5232            0    0  2883.189955  Intel Core i5    0    0
# 2   30636.0000            0    0  3842.979218  Intel Core i5  256    0
# 3  135195.3360            0    1  5763.896104  Intel Core i7  512    0
# 4   96095.8080            0    1  5124.253274  Intel Core i5  256    0
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS          ppi      Cpu Brand  SSD  HDD  \
# 0   71378.6832            0    1  5124.253274  Intel Core i5  128    0
# 1   47895.5232            0    0  2883.189955  Intel Core i5    0    0
# 2   30636.0000            0    0  3842.979218  Intel Core i5  256    0
# 3  135195.3360            0    1  5763.896104  Intel Core i7  512    0
# 4   96095.8080            0    1  5124.253274  Intel Core i5  256    0
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu Brand, dtype: int64

# %%
sns.barplot(x=df['Gpu Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13912\3949037655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#            ppi      Cpu Brand  SSD  HDD Gpu Brand
# 0  5124.253274  Intel Core i5  128    0     Intel
# 1  2883.189955  Intel Core i5    0    0     Intel
# 2  3842.979218  Intel Core i5  256    0     Intel
# 3  5763.896104  Intel Core i7  512    0       AMD
# 4  5124.253274  Intel Core i5  256    0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(x):
    if x=='Windows 10' or x=='Windows 7' or x=='Windows 10 5':
        return 'Windows'
    elif x=='macOS' or x=='Mac OS X':
        return 'Mac'
    else: 
        'other/No OS/Linux'

# %%
df['os']=df['OpSys'].apply(cat_os)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13912\3255695950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#            ppi      Cpu Brand  SSD  HDD Gpu Brand    os
# 0  5124.253274  Intel Core i5  128    0     Intel   Mac
# 1  2883.189955  Intel Core i5    0    0     Intel   Mac
# 2  3842.979218  Intel Core i5  256    0     Intel  None
# 3  5763.896104  Intel Core i7  512    0       AMD   Mac
# 4  5124.253274  Intel Core i5  256    0     Intel   Mac

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13912\3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS          ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  5124.253274
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  2883.189955
# 2      HP   Notebook    8    1.86   30636.0000            0    0  3842.979218
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  5763.896104
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  5124.253274
#
#        Cpu Brand  SSD  HDD Gpu Brand    os
# 0  Intel Core i5  128    0     Intel   Mac
# 1  Intel Core i5    0    0     Intel   Mac
# 2  Intel Core i5  256    0     Intel  None
# 3  Intel Core i7  512    0       AMD   Mac
# 4  Intel Core i5  256    0     Intel   Mac

# %%
sns.distplot(df['Weight'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x=df['Weight'], y=df['Price'])
plt.show()

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.557342
# SSD            0.552990
# HDD           -0.235122
# Name: Price, dtype: float64

# %%
df.describe()
# Out:
#                Ram       Weight          Price  Touchscreen         IPS  \
# count  1302.000000  1302.000000    1302.000000  1302.000000  1302.00000
# mean      8.385561     2.039416   59889.058673     0.146697     0.27957
# std       5.085166     0.665274   37251.183866     0.353940     0.44896
# min       2.000000     0.690000    9270.720000     0.000000     0.00000
# 25%       4.000000     1.500000   31914.720000     0.000000     0.00000
# 50%       8.000000     2.040000   52107.840000     0.000000     0.00000
# 75%       8.000000     2.300000   79303.816800     0.000000     1.00000
# max      64.000000     4.700000  324954.720000     1.000000     1.00000
#
#                ppi          SSD          HDD
# count  1302.000000  1302.000000  1302.000000
# mean   3791.883277   170.417819    51.943932
# std     989.668862   161.618954   151.864965
# min    2734.265424     0.000000     0.000000
# 25%    3202.452393     0.000000     0.000000
# 50%    3842.979218   128.000000     0.000000
# ...

# %%
sns.distplot(np.log(df['Price']))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df.describe()
# Out:
#                Ram       Weight          Price  Touchscreen         IPS  \
# count  1302.000000  1302.000000    1302.000000  1302.000000  1302.00000
# mean      8.385561     2.039416   59889.058673     0.146697     0.27957
# std       5.085166     0.665274   37251.183866     0.353940     0.44896
# min       2.000000     0.690000    9270.720000     0.000000     0.00000
# 25%       4.000000     1.500000   31914.720000     0.000000     0.00000
# 50%       8.000000     2.040000   52107.840000     0.000000     0.00000
# 75%       8.000000     2.300000   79303.816800     0.000000     1.00000
# max      64.000000     4.700000  324954.720000     1.000000     1.00000
#
#                ppi          SSD          HDD
# count  1302.000000  1302.000000  1302.000000
# mean   3791.883277   170.417819    51.943932
# std     989.668862   161.618954   151.864965
# min    2734.265424     0.000000     0.000000
# 25%    3202.452393     0.000000     0.000000
# 50%    3842.979218   128.000000     0.000000
# ...

# %%
x=df.drop('Price', axis=1)
y=np.log(df['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS          ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  5124.253274
# 1      Apple           Ultrabook    8    1.34            0    0  2883.189955
# 2         HP            Notebook    8    1.86            0    0  3842.979218
# 3      Apple           Ultrabook   16    1.83            0    1  5763.896104
# 4      Apple           Ultrabook    8    1.37            0    1  5124.253274
# ...      ...                 ...  ...     ...          ...  ...          ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  3843.319700
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  6404.511278
# 1300  Lenovo            Notebook    2    1.50            0    0  2734.799417
# 1301      HP            Notebook    6    2.19            0    0  2734.512297
# 1302    Asus            Notebook    4    2.20            0    0  2734.512297
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.20, random_state=42
)

# %%
x_train.shape
# Out:
# (1041, 12)

# %%
x_test.shape
# Out:
# (261, 12)

# %%
y_train.shape
# Out:
# (1041,)

# %%
x_test.shape
# Out:
# (261, 12)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first'),[0,1,7,10,11])
], remainder='passthrough')

step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8029472038036753
# MAE 0.21809725385325365
# 0.8029472038036753

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=Ridge()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8030459027524257
# MAE 0.21881780218710695
# 0.8030459027524257

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=Lasso(alpha=0.001)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.7991394570666273
# MAE 0.22192982621891927
# 0.7991394570666273

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=KNeighborsRegressor(n_neighbors=2)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8110736011512165
# MAE 0.19653690381543926
# 0.8110736011512165

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=DecisionTreeRegressor(max_depth=8)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8018739569332274
# MAE 0.2061209193971829
# 0.8018739569332274

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=SVR(kernel='rbf', C=10000)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.7247502508849775
# MAE 0.26819315097739355
# 0.7247502508849775

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=RandomForestRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75, max_depth=15)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8559764518934337
# MAE 0.1777009313278801
# 0.8559764518934337

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=AdaBoostRegressor(n_estimators=30, learning_rate=1.0)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.7766156437056713
# MAE 0.24478720898192155
# 0.7766156437056713

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=GradientBoostingRegressor(n_estimators=600)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8719080073074186
# MAE 0.16938159611314346
# 0.8719080073074186

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')

step2=XGBRegressor()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8771390985366203
# MAE 0.15810957379306567
# 0.8771390985366203

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse=False),[0,1,7,10,11])
], remainder='passthrough')


xgb=XGBRegressor()
gbr=GradientBoostingRegressor(n_estimators=600)
rf=RandomForestRegressor(n_estimators=100, random_state=3, max_samples=0.5, max_features=0.75, max_depth=15)

step2=VotingRegressor([('rf',rf),('gbr',gbr),('xgb',xgb)])


pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))

pipe.score(x_test, y_test)
# Out:
# R2 Score 0.8821259184495699
# MAE 0.1602961160563193
# 0.8821259184495699

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_absolute_error
from xgboost import XGBRegressor

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(drop='first', sparse=False),
         [0,1,7,10,11])
    ],
    remainder='passthrough'
)

estimators = [
    ('rf', RandomForestRegressor(
        n_estimators=100,
        random_state=3,
        max_samples=0.5,
        max_features=0.75,
        max_depth=15
    )),
    
    ('gbr', GradientBoostingRegressor(
        n_estimators=600
    )),
    
    ('xgb', XGBRegressor())
]

step2 = StackingRegressor(
    estimators=estimators,
    final_estimator=Ridge()
)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))

print("Pipeline Score:", pipe.score(x_test, y_test))
# Out:
# R2 Score: 0.8796262732960906
# MAE: 0.16374456813644897
# Pipeline Score: 0.8796262732960906

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# Save the Data 
df_clean.to_csv(r'D:\Data_Set\clean_laptop_data.csv', index=False)

# %%
# Cleaned dataframe
df_clean = df.copy()

# Save to CSV
df_clean.to_csv('clean_laptop_data.csv', index=False)
